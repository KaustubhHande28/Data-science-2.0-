# %%
import pandas as pd
import numpy as np

# %%
sales_df=pd.read_csv('Advertising Budget and Sales.csv')
sales_df
# Out:
#      Unnamed: 0  TV Ad Budget ($)  Radio Ad Budget ($)  \
# 0             1             230.1                 37.8
# 1             2              44.5                 39.3
# 2             3              17.2                 45.9
# 3             4             151.5                 41.3
# 4             5             180.8                 10.8
# ..          ...               ...                  ...
# 195         196              38.2                  3.7
# 196         197              94.2                  4.9
# 197         198             177.0                  9.3
# 198         199             283.6                 42.0
# 199         200             232.1                  8.6
#
#      Newspaper Ad Budget ($)  Sales ($)
# 0                       69.2       22.1
# 1                       45.1       10.4
# 2                       69.3        9.3
# 3                       58.5       18.5
# 4                       58.4       12.9
# ..                       ...        ...
# ...

# %%
sales_df=pd.read_csv('Advertising Budget and Sales.csv')
sales_df.head()
# Out:
#    Unnamed: 0  TV Ad Budget ($)  Radio Ad Budget ($)  Newspaper Ad Budget ($)  \
# 0           1             230.1                 37.8                     69.2
# 1           2              44.5                 39.3                     45.1
# 2           3              17.2                 45.9                     69.3
# 3           4             151.5                 41.3                     58.5
# 4           5             180.8                 10.8                     58.4
#
#    Sales ($)
# 0       22.1
# 1       10.4
# 2        9.3
# 3       18.5
# 4       12.9

# %%
sales_df.tail()
# Out:
#      Unnamed: 0  TV Ad Budget ($)  Radio Ad Budget ($)  \
# 195         196              38.2                  3.7
# 196         197              94.2                  4.9
# 197         198             177.0                  9.3
# 198         199             283.6                 42.0
# 199         200             232.1                  8.6
#
#      Newspaper Ad Budget ($)  Sales ($)
# 195                     13.8        7.6
# 196                      8.1        9.7
# 197                      6.4       12.8
# 198                     66.2       25.5
# 199                      8.7       13.4

# %%
#It will give all info of dataset
#if datatype shows obj64 it means that column contain string
sales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0               200 non-null    int64
#  1   TV Ad Budget ($)         200 non-null    float64
#  2   Radio Ad Budget ($)      200 non-null    float64
#  3   Newspaper Ad Budget ($)  200 non-null    float64
#  4   Sales ($)                200 non-null    float64
# dtypes: float64(4), int64(1)
# memory usage: 7.9 KB

# %%
sales_df.count()
# Out:
# Unnamed: 0                 200
# TV Ad Budget ($)           200
# Radio Ad Budget ($)        200
# Newspaper Ad Budget ($)    200
# Sales ($)                  200
# dtype: int64

# %%
#if we will call sales_df than bydefault it will show 1st five rows and last five rows
sales_df
# Out:
#      Unnamed: 0  TV Ad Budget ($)  Radio Ad Budget ($)  \
# 0             1             230.1                 37.8
# 1             2              44.5                 39.3
# 2             3              17.2                 45.9
# 3             4             151.5                 41.3
# 4             5             180.8                 10.8
# ..          ...               ...                  ...
# 195         196              38.2                  3.7
# 196         197              94.2                  4.9
# 197         198             177.0                  9.3
# 198         199             283.6                 42.0
# 199         200             232.1                  8.6
#
#      Newspaper Ad Budget ($)  Sales ($)
# 0                       69.2       22.1
# 1                       45.1       10.4
# 2                       69.3        9.3
# 3                       58.5       18.5
# 4                       58.4       12.9
# ..                       ...        ...
# ...

# %%
#describe: it describe the total data [ mean,standard deviation,minmum,maximum,mode]
#meausure of despertioin : variance , standard deviation & range
#meansure of center tendency : mean, mode,median
'''
(25%,50%,75%) tells us how the quantiles is showing data
second quantiles + median
'''
sales_df.describe()
# Out:
#        Unnamed: 0  TV Ad Budget ($)  Radio Ad Budget ($)  \
# count  200.000000        200.000000           200.000000
# mean   100.500000        147.042500            23.264000
# std     57.879185         85.854236            14.846809
# min      1.000000          0.700000             0.000000
# 25%     50.750000         74.375000             9.975000
# 50%    100.500000        149.750000            22.900000
# 75%    150.250000        218.825000            36.525000
# max    200.000000        296.400000            49.600000
#
#        Newspaper Ad Budget ($)   Sales ($)
# count               200.000000  200.000000
# mean                 30.554000   14.022500
# std                  21.778621    5.217457
# min                   0.300000    1.600000
# 25%                  12.750000   10.375000
# 50%                  25.750000   12.900000
# 75%                  45.100000   17.400000
# max                 114.000000   27.000000

# %%
sales_df.mode()
# Out:
#      Unnamed: 0  TV Ad Budget ($)  Radio Ad Budget ($)  \
# 0             1              17.2                  4.1
# 1             2              76.4                  5.7
# 2             3             109.8                  NaN
# 3             4             177.0                  NaN
# 4             5             184.9                  NaN
# ..          ...               ...                  ...
# 195         196               NaN                  NaN
# 196         197               NaN                  NaN
# 197         198               NaN                  NaN
# 198         199               NaN                  NaN
# 199         200               NaN                  NaN
#
#      Newspaper Ad Budget ($)  Sales ($)
# 0                        8.7        9.7
# 1                        9.3        NaN
# 2                       25.6        NaN
# 3                        NaN        NaN
# 4                        NaN        NaN
# ..                       ...        ...
# ...

# %%
sales_df.mean()
# Out:
# Unnamed: 0                 100.5000
# TV Ad Budget ($)           147.0425
# Radio Ad Budget ($)         23.2640
# Newspaper Ad Budget ($)     30.5540
# Sales ($)                   14.0225
# dtype: float64

# %%
sales_df.median()
# Out:
# Unnamed: 0                 100.50
# TV Ad Budget ($)           149.75
# Radio Ad Budget ($)         22.90
# Newspaper Ad Budget ($)     25.75
# Sales ($)                   12.90
# dtype: float64

# %%
sales_df.quantile(0.25)
# Out:
# Unnamed: 0                 50.750
# TV Ad Budget ($)           74.375
# Radio Ad Budget ($)         9.975
# Newspaper Ad Budget ($)    12.750
# Sales ($)                  10.375
# Name: 0.25, dtype: float64

# %%
sales_df.quantile(0.50)
# Out:
# Unnamed: 0                 100.50
# TV Ad Budget ($)           149.75
# Radio Ad Budget ($)         22.90
# Newspaper Ad Budget ($)     25.75
# Sales ($)                   12.90
# Name: 0.5, dtype: float64

# %%
sales_df.quantile(0.75)
# Out:
# Unnamed: 0                 150.250
# TV Ad Budget ($)           218.825
# Radio Ad Budget ($)         36.525
# Newspaper Ad Budget ($)     45.100
# Sales ($)                   17.400
# Name: 0.75, dtype: float64

# %%
#if we want mean of particular column
sales_df['TV Ad Budget ($)'].mean()
# Out:
# 147.0425
